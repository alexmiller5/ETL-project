# %%
import pandas as pd

# %%
# File to Load
state_candy_path = "st_can_nut.csv"

# Read the modified csv and store into Pandas DataFrame
state_candy_df = pd.read_csv(state_candy_path, encoding="utf-8")
state_candy_df
# Out:
#               state                        candy  calories  fat(G)  sugar(G)
# 0           Hawaii                 100 Grand Bar        95     4.0      11.0
# 1        Minnesota                 100 Grand Bar        95     4.0      11.0
# 2         Delaware                  3 Musketeers        63     2.0      10.0
# 3       New Mexico                  3 Musketeers        63     2.0      10.0
# 4          Alabama                      AirHeads        45     1.3       6.0
# 5       Washington                      AirHeads        45     1.3       6.0
# 6         Maryland                    Almond Joy        80     4.5       8.0
# 7          Vermont                    Almond Joy        80     4.5       8.0
# 8            Idaho                  Butterfinger        85     4.0      10.0
# 9   North Carolina                  Butterfinger        85     4.0      10.0
# 10          Oregon                    Candy corn        75     0.0      16.5
# ...

# %%
# File to Load
oral_health_path = "oral_health.csv"

# Read the modified csv and store into Pandas DataFrame
oral_health_df = pd.read_csv(oral_health_path, encoding="utf-8")
oral_health_df
# Out:
#              state  Overall Score  Overall Rank  Habits & Care Score  \
# 0          Alabama           54.5            45                 30.9
# 1           Alaska           57.7            42                 48.2
# 2          Arizona           64.5            36                 30.8
# 3         Arkansas           39.2            50                 24.1
# 4       California           66.8            34                 45.0
# 5         Colorado           80.9            19                 53.3
# 6      Connecticut          100.5             2                 55.5
# 7         Delaware           70.6            28                 42.0
# 8          Florida           56.8            43                 30.5
# 9          Georgia           63.8            39                 35.4
# 10          Hawaii           72.2            27                 33.2
# 11           Idaho           68.1            30                 41.6
# 12        Illinois          100.1             3                 44.3
# ...

# %%
#IF everything had gone to plan the dfs would have lined up and come out as this but I did a little cleaning and combining in excel
combined_path = "combined.csv"

# Read the modified csv and store into Pandas DataFrame
combined_df = pd.read_csv(combined_path, encoding="utf-8")
combined_df
# Out:
#               state                        Candy  cal  fat(g)  sugar(g)  \
# 0          Alabama                      AirHeads   45     1.3       6.0
# 1           Alaska                      Snickers   80     4.0       8.5
# 2          Arizona                     Toblerone   90     5.0      10.0
# 3         Arkansas                      Skittles   80     0.8      14.5
# 4       California                    Lifesavers   45     0.0       9.0
# 5         Colorado                     Milky Way   80     3.0      10.0
# 6      Connecticut    Reese's Peanut Butter Cups  110     6.5      10.5
# 7         Delaware                  3 Musketeers   63     2.0      10.0
# 8          Florida             Nestlé Crunch Bar   60     3.0       7.0
# 9          Georgia                     Pixy Stix   60     0.0      15.0
# 10          Hawaii                 100 Grand Bar   95     4.0      11.0
# 11           Idaho                  Butterfinger   85     4.0      10.0
# ...

# %%
#I attempted to drop columns and just finished the thing in excel. I'll ask how to afterward.
#I shouldn't be under time constraints but here I am just need to turn in project.
